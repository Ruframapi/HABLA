# %%
# %cd /content/drive/MyDrive/Tesis/anti-spoof-eval/03-asvspoof-mega
# Out:
# /content/drive/MyDrive/Tesis/anti-spoof-eval/03-asvspoof-mega

# %%
# !python main.py --inference --model-forward-with-file-name --trained-model trained_network_fixed.pt > log_output_testset_pretrained_fixed 2>log_output_testset_pretrained_err_fixed

# %% [markdown]
# # fine tune

# %%
# !python main.py --model-forward-with-file-name --trained-model trained_network_fix.pt  --num-workers 3 --epochs 50 --no-best-epochs 10 --batch-size 64 --sampler block_shuffle_by_length --lr-decay-factor 0.5 --lr-scheduler-type 1 --lr 0.0003   --seed 1 > log_train_ft 2>log_err_ft
