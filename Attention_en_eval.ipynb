# %%
# %cd /content/drive/MyDrive/Tesis/anti-spoof-eval/03-asvspoof-mega
# Out:
# /content/drive/MyDrive/Tesis/anti-spoof-eval/03-asvspoof-mega

# %%
# !python main.py --inference --model-forward-with-file-name --trained-model trained_network_att.pt > log_output_testset_pretrained_att 2>log_output_testset_pretrained_err_att

# %% [markdown]
# ## fine tunning

# %%
# !python main.py --model-forward-with-file-name --trained-model trained_network_att.pt  --num-workers 3 --epochs 50 --no-best-epochs 10 --batch-size 64 --sampler block_shuffle_by_length --lr-decay-factor 0.5 --lr-scheduler-type 1 --lr 0.0003   --seed 1 > log_train_att 2>log_err_att

# %%
# !python main.py --inference --model-forward-with-file-name --trained-model trained_network_finetune_att.pt > log_output_testset_pretrained__ft_att_eng 2>log_output_testset_pretrained_err_ft_att_eng
