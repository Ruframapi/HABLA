# %%
# %cd /content/drive/MyDrive/Tesis/anti-spoof-eval/03-asvspoof-mega
# Out:
# /content/drive/MyDrive/Tesis/anti-spoof-eval/03-asvspoof-mega

# %%
# !python main.py --inference --model-forward-with-file-name --trained-model trained_network_lfcc-lcnn-lstm_spanish.pt > log_output_testset_pretrained_lstm 2>log_output_testset_pretrained_err_lstm

# %% [markdown]
# ## fine-tunning

# %%
# !python main.py --model-forward-with-file-name --trained-model trained_network_lstm.pt  --num-workers 3 --epochs 50 --no-best-epochs 10 --batch-size 64 --sampler block_shuffle_by_length --lr-decay-factor 0.5 --lr-scheduler-type 1 --lr 0.0003   --seed 1 > log_train_ft_lstm 2>log_err_ft_lstm

# %%
# !python main.py --inference --model-forward-with-file-name --trained-model trained_network_finetune_lstm.pt > log_output_testset_pretrained_ft_lstm_eng 2>log_output_testset_pretrained_err_ft_lstm_eng
